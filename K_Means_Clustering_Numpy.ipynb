# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np

# %%
data=pd.read_csv("Clustering_gmm.csv")
data.shape
# Out:
# (500, 2)

# %%
plt.figure(figsize=(10,6))
plt.scatter(data["Weight"],data["Height"],marker="*",color="red")
data.head()
plt.xlabel("Weights",size=30)
plt.ylabel("Heights",size=30)
plt.xticks(size=15)
plt.yticks(size=15)
# Out:
# (array([157.5, 160. , 162.5, 165. , 167.5, 170. , 172.5, 175. , 177.5,
#         180. ]), <a list of 10 Text major ticklabel objects>)

# %%
from sklearn.cluster import KMeans

# %%
kmeans=KMeans(n_clusters=3)

# %%
kmeans.fit(data)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=3, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
pred=kmeans.predict(data)

# %%
frame=pd.DataFrame(data)

# %%
frame["cluster"]=pred

# %%
kmeans.cluster_centers_
# Out:
# array([[ 67.48040873, 175.86017523],
#        [ 53.60029808, 162.76478198],
#        [ 61.91101547, 169.61922731]])

# %%
for i in range(3):
  data=frame[frame["cluster"]==i]
  plt.scatter(data["Weight"],data["Height"])

# %% [markdown]
# ### K means Using Numpy

# %%
df=pd.read_csv("Clustering_gmm.csv")
df.head()
n_centers=3

# %%
df.head()
# Out:
#       Weight      Height
# 0  67.062924  176.086355
# 1  68.804094  178.388669
# 2  60.930863  170.284496
# 3  59.733843  168.691992
# 4  65.431230  173.763679

# %%
centers=df.sample(n=n_centers)
iterations=300
for l in range(iterations):
   assigned_labels=[]
   for i in df.iloc[:,:2].values:
      z=[]
      for j in centers.values:
        z.append(np.linalg.norm(i-j,2))
      assigned_labels.append(np.argmin(z))  
   df["center"]=assigned_labels
   centroids=[]
   for k in range(n):
     centroids.append(df[df["center"]==k].values[:,:2].mean(axis=0))
centers=pd.DataFrame(centroids)
centers.columns=["Weight","Height"]

# %%
plt.figure(figsize=(8,5))
colors=["yellow","g","r","black"]
for i in range(n):
  dataframe=df[df["center"]==i]
  plt.scatter(dataframe["Weight"],dataframe["Height"])
  plt.plot(centers["Weight"].values[i],centers["Height"].values[i],color="red",marker='.', markersize=90,markerfacecolor=colors[i],
         markeredgecolor='black',
         markeredgewidth=7,label="Centroid 1")
  plt.xlabel("Weights",size=30)
  plt.ylabel("Heights",size=30)
  plt.xticks(size=15)
  plt.yticks(size=15)
  plt.

# %%
centers["Weight"].values[0]
# Out:
# 56.02376450677176

# %%
centers
# Out:
#       Weight      Height
# 0  59.414779  167.246459
# 1  56.083613  165.729322
# 2  65.991898  173.554192

# %%
df.head(10)
# Out:
#       Weight      Height  center
# 0  67.062924  176.086355       2
# 1  68.804094  178.388669       2
# 2  60.930863  170.284496       0
# 3  59.733843  168.691992       0
# 4  65.431230  173.763679       2
# 5  61.577160  168.091751       0
# 6  63.341866  170.642516       0
# 7  61.041643  170.096682       0
# 8  62.633623  171.862972       2
# 9  53.407860  162.756843       1
